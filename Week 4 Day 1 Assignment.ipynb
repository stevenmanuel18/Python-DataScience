# %% [markdown]
# <h1>Soal 1: Pemahaman Machine Learning</h1>
#
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri:
#
# - Apa itu machine learning?
# - Apa itu data feature dan data target?
# - Apa Perbedaan Supervised Learning dan Unsupervised Learning?
# - Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# - Apa perbedaan Hyperparameter dan Parameter?
# - Sebutkan Langkah-langkah dalam mengaplikasikan algoritma apapun dalam machine learning!

# %% [markdown]
# - Machine Learning adalah aplikasi dari kecerdasan buatan dimana sistem diberikan kemampuan untuk belajar sendiri tanpa harus diprogram ulang oleh manusia
# - Data feature adalah data yang diambil sebagai nilai prediksi yang nantinya akan dikelompokan atau dilabeli sebagai data target
# - Perbedaannya adalah Supervised learning memilki label/data target sedangkan unsupervised learning tidak sehingga hasil olahan komputer pada unsupervised learning hanya menghasilkan pola tertentu dari data
# - Regression dan classification. Regression adalah jenis supervised learning dimana komputer mempelajari pola pada data yang berupa data kontinu dan menghasilkan suatu garis prediksi sehingga jika ada data baru, sistem dapat mengetahui data targetnya. Classification adalah jenis supervised learning dimana data dikategorikan berdasarkan labelnya, data berupa diskrit.
# - Hyperparameter dibuat diawal pengolahan dan digunakan agar mendapatkan hasil yang optimal sedangkan parameter didapat di akhir proses.
# - Langkah aplikasi algoritma pada machine learning
#     1. Pilih model yang digunakan
#     2. Pilih hypermeter
#     3. Pisahkan feature dan target
#     4. Mempelajari data dengan .fit()
#     5. Pengaplikasian model pada test data dengan menggunakan .predict() pada supervised dan .transform() serta .predict() pada unsupervised

# %% [markdown]
# <h1>Soal 2: Pemahaman Machine Learning</h1>
#
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian aplikasikan untuk membuat model bagi data (variable x, y) di bawah ini. Kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
#
# - Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# - Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)

# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y)
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.show()

# %% [markdown]
# Contoh jawaban hasil pembuatan model dengan algoritma DecisionTreeRegressor (jawaban tidak harus sama):
#
# ![alt text](https://drive.google.com/uc?id=1R0mGnMp3DqEsHDiH2_IL4XSS2Roew0wo)

# %% [markdown]
# Contoh jawaban parameters (tidak harus sama):
#
# - Feature Importance : array([1.])
# - n features : 1
#
# Tree Graph :
#
# ![alt text](https://drive.google.com/uc?id=1GM0ba_qjm_e5oLhE9v6pVt2uRBBW6FH9)

# %%
# Code here
from sklearn.tree import DecisionTreeRegressor

reg = DecisionTreeRegressor()
x_matrix = x[: ,np.newaxis]

# %%
# Fit
reg.fit(x_matrix, y)
# Out:
# DecisionTreeRegressor()

# %%
# Predict
x_test = x_new[: ,np.newaxis]
y_test = reg.predict(x_test)

y_train = reg.predict(x_matrix)

# %%
plt.scatter(x, y, label='Data')
plt.plot(x_test, y_test, label='Prediksi Terhadap Data Baru', color='g')
plt.legend()
plt.show()

# %%
import inspect
import sklearn

# %%
parameter = inspect.getargspec(sklearn.tree.DecisionTreeRegressor.__init__).args
print(parameter)
# Out:
# []
# <ipython-input-7-2d92b52cc587>:1: DeprecationWarning: inspect.getargspec() is deprecated since Python 3.0, use inspect.signature() or inspect.getfullargspec()
#   parameter = inspect.getargspec(sklearn.tree.DecisionTreeRegressor.__init__).args
